# %% [markdown]
# # 🛸 Mission Control: Route Optimization v1
#
# Initial notebook for the Omiroute routing pipeline.

# %%
# !pip install -q omiroute-sdk openai python-dotenv

# %%
import os
from dotenv import load_dotenv

load_dotenv()
print("🛰️ Mission Control: Notebook successfully bound to project workspace.")

# %% [markdown]
# ## Next Steps
# - Add your API keys to `.env`
# - Configure routing logic in `config/routes.yaml`
# - Store datasets in `data/`
