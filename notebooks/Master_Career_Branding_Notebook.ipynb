# %% [markdown]
# # 🎯 Sam Leong — Master Career Branding Notebook
#
# **Candidate:** Sam Leong (Josen Leong Chong Kwee)
# **Role Target:** Senior Transformation Leader & Enterprise AI Practitioner
# **Location:** Singapore (APAC Regional Hub)
# **Contact:** silentious@outlook.com | +65 8917 2828
# **LinkedIn:** https://linkedin.com/in/samleong2828/
# **System:** RAIN-CAG 34 Master Career Branding Project
#
# ---

# %% [markdown]
# ## 📊 Candidate Profile Snapshot

# %%
candidate_profile = {
    "full_name": "Sam Leong (Josen Leong Chong Kwee)",
    "location": "Singapore (APAC Regional Hub)",
    "email": "silentious@outlook.com",
    "phone": "+65 8917 2828",
    "linkedin": "https://linkedin.com/in/samleong2828/",
    "linkedin_connections": "1,000+",
    "target_compensation_floor": "S$120K – S$144K+ per annum",
    "offer_premium_target": "15–25%",
    "years_experience": "30+",
    "sap_mm_cert_id": "dvi26arefp9n",
    "imda_governance": "v1.5",
    "target_role_vectors": [
        "Head of Global Distribution / Export (Stamford Tyres International)",
        "Senior Transformation & Enterprise AI Practice Lead",
        "Regional Supply Chain & ERP Modernization Specialist (SAP MM)"
    ]
}

candidate_profile

# %% [markdown]
# ---
#
# ## ⚙️ Tier 1: Core Career Branding Files

# %%
# Tier 1: Core Assets
tier1_assets = {
    "cv_suite": {
        "primary": "Resume_Sam_Leong_Stamford_Tyres_International_Pte_Ltd.md",
        "maersk": "CV_1_Maersk_Regional_Head_Chartering.md",
        "maersk_alt": "CV_2_Maersk_Operational_Excellence.md",
        "google_cloud": "CV_3_Google_Cloud_APAC_Strategic_Engagement.md",
        "tiktok": "CV_4_TikTok_Eco_Project_Manager.md",
        "aws": "CV_5_AWS_Principal_Partner_Development_AI.md",
        "version": "v2.4-ST",
        "ats_match_score": "96.8%"
    },
    "cover_letters": {
        "master": "Cover_Letter_Master_Sam_Leong.md",
        "variant_a_stamford_tyres": "Cover_Letter_Variant_A_Global_Distribution.md",
        "variant_b_enterprise_ai": "Cover_Letter_Variant_B_Enterprise_AI.md",
        "variant_c_sap_mm": "Cover_Letter_Variant_C_SAP_MM.md"
    },
    "executive_dossier": "docs/Executive_Dossier_Gemini_AI.md",
    "career_branding_chapter": "docs/chapter-career-branding-final-goals.md",
    "podcast_transcript": "audio/Podcast_Transcript_Final_Goals.md"
}

print("✅ Tier 1 Core Assets Loaded")
print(f"CV Suite: {len(tier1_assets['cv_suite'])} variants (v{tier1_assets['cv_suite']['version']})")
print(f"Cover Letters: {len(tier1_assets['cover_letters'])} files")
print(f"Executive Dossier: {tier1_assets['executive_dossier']}")
print(f"Career Branding Chapter: {tier1_assets['career_branding_chapter']}")
print(f"Podcast Transcript: {tier1_assets['podcast_transcript']}")

# %% [markdown]
# ---
#
# ## 📈 Key Metrics & Achievements

# %%
import pandas as pd

metrics_data = {
    "Metric": [
        "Years of Experience",
        "APAC Markets Penetrated",
        "Monthly Outbound Shipments",
        "On-Time Delivery Rate",
        "Logistics Efficiency Gain (AI)",
        "Procurement Cycle Time Reduction (SAP MM)",
        "Pipeline Growth (Partnerships)",
        "Logistics Partners Engaged",
        "LinkedIn Network",
        "ATS Match Score",
        "Compensation Floor"
    ],
    "Value": [
        "30+",
        "8",
        "120+",
        "98.5%",
        "30%",
        "20%",
        "35%",
        "50+",
        "1,000+",
        "96.8%",
        "S$120K–S$144K+"
    ]
}

df_metrics = pd.DataFrame(metrics_data)
df_metrics

# %% [markdown]
# ---
#
# ## 🎯 Application Packages (Recruiter-Ready)

# %%
application_packages = {
    "Stamford Tyres International": {
        "role": "Head of Global Distribution / Export",
        "cv": "Resume_Sam_Leong_Stamford_Tyres_International_Pte_Ltd.md",
        "cover_letter": "Cover_Letter_Variant_A_Global_Distribution.md",
        "dossier": "docs/Executive_Dossier_Gemini_AI.md",
        "status": "🟢 DEPLOYMENT-READY"
    },
    "Maersk": {
        "role": "Regional Head of Chartering / Operational Excellence",
        "cv": "CV_1_Maersk_Regional_Head_Chartering.md",
        "cover_letter": "Cover_Letter_Master_Sam_Leong.md",
        "dossier": "docs/Executive_Dossier_Gemini_AI.md",
        "status": "🟢 DEPLOYMENT-READY"
    },
    "Google Cloud": {
        "role": "APAC Strategic Engagement / Enterprise AI",
        "cv": "CV_3_Google_Cloud_APAC_Strategic_Engagement.md",
        "cover_letter": "Cover_Letter_Variant_B_Enterprise_AI.md",
        "dossier": "docs/Executive_Dossier_Gemini_AI.md",
        "status": "🟢 DEPLOYMENT-READY"
    },
    "TikTok": {
        "role": "Eco Project Manager / Digital Transformation",
        "cv": "CV_4_TikTok_Eco_Project_Manager.md",
        "cover_letter": "Cover_Letter_Master_Sam_Leong.md",
        "dossier": "docs/Executive_Dossier_Gemini_AI.md",
        "status": "🟢 DEPLOYMENT-READY"
    },
    "AWS": {
        "role": "Principal Partner Development / AI",
        "cv": "CV_5_AWS_Principal_Partner_Development_AI.md",
        "cover_letter": "Cover_Letter_Variant_C_SAP_MM.md",
        "dossier": "docs/Executive_Dossier_Gemini_AI.md",
        "status": "🟢 DEPLOYMENT-READY"
    }
}

df_apps = pd.DataFrame.from_dict(application_packages, orient='index')
df_apps[['role', 'cv', 'cover_letter', 'status']]

# %% [markdown]
# ---
#
# ## 🛡️ System Governance

# %%
governance = {
    "system_name": "RAIN-CAG 34 Master System Architecture",
    "document_control_id": "ARCH-SPEC-RAIN34-20260806",
    "archive_lock_id": "ARCHIVE-20260826-001",
    "system_registry": "registry/omniroute-master-registry-gemini-merged.json",
    "change_log": "CHANGE_LOG.md",
    "rewrite_policy": "tier4-governance/rewrite-governance-policy.md",
    "total_agents": 34,
    "tiers": {
        "Tier 1 - Core Assets": "5 agents (LOCKED)",
        "Tier 2 - Metrics & Analytics": "5 agents (ACTIVE)",
        "Tier 3 - Outreach & Visibility": "6 agents (ACTIVE)",
        "Tier 4 - Governance & Control": "5 agents (ENFORCED)",
        "Tier 5 - Supporting": "13 agents (ALIGNED)"
    }
}

print("🛡️ System Governance Loaded")
print(f"System: {governance['system_name']}")
print(f"Total Agents: {governance['total_agents']}")
print(f"Registry: {governance['system_registry']}")
print(f"Change Log: {governance['change_log']}")

# %% [markdown]
# ---
#
# ## 📁 Workspace File Index

# %%
import os
from pathlib import Path

workspace_root = Path("/Volumes/Orico e7400 1TB/my-project")
key_files = [
    "README.md",
    "CHANGE_LOG.md",
    "registry/omniroute-master-registry-gemini-merged.json",
    "Resume_Sam_Leong_Stamford_Tyres_International_Pte_Ltd.md",
    "Cover_Letter_Master_Sam_Leong.md",
    "Executive_Dossier_Sam_Leong.md",
    "chapter-career-branding-final-goals.md",
    "Master_Portfolio_Binder_Sam_Leong.md",
    "CV_1_Maersk_Regional_Head_Chartering.md",
    "CV_2_Maersk_Operational_Excellence.md",
    "CV_3_Google_Cloud_APAC_Strategic_Engagement.md",
    "CV_4_TikTok_Eco_Project_Manager.md",
    "CV_5_AWS_Principal_Partner_Development_AI.md"
]

file_status = []
for f in key_files:
    path = workspace_root / f
    exists = "✅" if path.exists() else "❌"
    size = path.stat().st_size if path.exists() else 0
    file_status.append({"File": f, "Status": exists, "Size (bytes)": size})

df_files = pd.DataFrame(file_status)
df_files

# %% [markdown]
# ---
#
# ## 🚀 Quick Actions

# %%
print("📋 Quick Actions Available:")
print("1. View CV: Resume_Sam_Leong_Stamford_Tyres_International_Pte_Ltd.md")
print("2. View Cover Letters: docs/Cover_Letter_Master_Sam_Leong.md")
print("3. View Dossier: docs/Executive_Dossier_Gemini_AI.md")
print("4. View Application Packages: Application_Package_*.md")
print("5. View Change Log: CHANGE_LOG.md")
print("6. View Agent Specs: tier1-core-assets/ through tier5-supporting/")
print("\n✅ All files are live, editable, and deployment-ready.")
