# %% [markdown]
# # Experiment: Stripe Payment Integration Setup
#
# Objective:
# - State the question to answer.
# - Define the success criteria.

# %%
# Stripe Integration Setup
import os
import stripe

# Set your Stripe keys from environment variables
STRIPE_PUBLIC_KEY = os.getenv("STRIPE_PUBLIC_KEY", "pk_test_...")
STRIPE_SECRET_KEY = os.getenv("STRIPE_SECRET_KEY", "sk_test_...")
STRIPE_WEBHOOK_SECRET = os.getenv("STRIPE_WEBHOOK_SECRET", "whsec_...")

# Initialize Stripe client
stripe.api_key = STRIPE_SECRET_KEY

# Configuration
PRICE_STARTER = "price_1QafL2LKxyzabc12345"  # QAFlow AI Starter
PRICE_PRO = "price_1QafL3LKxyzabc123456"  # QAFlow AI Pro
PRICE_LAUNCH = "price_1QafL4LKxyzabc1234567"  # QAFlow AI Launch

# Create a test customer
customer = stripe.Customer.create(
    email="test@example.com",
    name="Test User"
)

# %%
# Setup: imports, configuration, and reproducibility
from __future__ import annotations

import random

SEED = 7
random.seed(SEED)

# %% [markdown]
# ## Plan
#
# - Hypothesis:
# - Variables to change:
# - Metrics to record:

# %%
# Start with the smallest end-to-end baseline

# %% [markdown]
# ## Results
#
# - Key observations:
# - Important metrics:
# - Surprises or failure modes:

# %% [markdown]
# ## Next steps
#
# - Decision: continue, pivot, or stop.
# - Follow-up ideas:
